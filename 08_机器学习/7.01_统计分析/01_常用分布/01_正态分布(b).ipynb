# %% [markdown]
# # 01 正态分布

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import matplotlib.style as style
from IPython.core.display import HTML

style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (14, 7)
plt.figure(dpi=100)

# PDF(概率密度)
plt.plot(np.linspace(-4, 4, 100),
        stats.norm.pdf(np.linspace(-4, 4, 100)) / np.max(stats.norm.pdf(np.linspace(-3, 3, 100))),)

plt.fill_between(np.linspace(-4, 4, 100),
                stats.norm.pdf(np.linspace(-4, 4, 100)) / np.max(stats.norm.pdf(np.linspace(-3, 3, 100))),
                alpha=.15,)

# CDF(累积概率密度)
plt.plot(np.linspace(-4, 4, 100),
        stats.norm.cdf(np.linspace(-4, 4, 100)))

# LEGEND
plt.text(x=-1.5, y=.7, s="pdf(normed)", rotation=65, alpha=.75, weight='bold', color='#008fd5')
plt.text(x=-0.4, y=.5, s='cdf', rotation=55, alpha=.75, weight='bold', color='#fc4f30')

# TICKS
plt.tick_params(axis='both', which='major', labelsize=18)
plt.axhline(y=0, color='black', linewidth=1.3, alpha=.7)

# TITLE
plt.text(x=-5, y=1.25, s='Normal Distibution - Overview', fontsize=26, weight='bold', alpha=0.75)
plt.text(x=-5, y=1.1,
        s='Depicted below are the normed probability density function (pdf) and the cumulative density\nfunction (cdf) of a normally distributed random variable $ y \\ sim \\mathcal{N} (\\mu, \\sigma) $, given $ \\mu = 0 $ and $ \\sigma = 1 $.',
        fontsize=19, alpha=.85)
# Out:
# Text(-5, 1.1, 'Depicted below are the normed probability density function (pdf) and the cumulative density\nfunction (cdf) of a normally distributed random variable $ y \\ sim \\mathcal{N} (\\mu, \\sigma) $, given $ \\mu = 0 $ and $ \\sigma = 1 $.')

# %% [markdown]
# ## 1.1 均值($ \mu $)

# %%
plt.figure(dpi=100)

# PDF MU = 0
plt.plot(np.linspace(-4, 4, 100),
        stats.norm.pdf(np.linspace(-4, 4, 100)),
        )
plt.fill_between(np.linspace(-4, 4, 100),
        stats.norm.pdf(np.linspace(-4, 4, 100)),
        alpha=.15
        )

# PDF MU = 2
plt.plot(np.linspace(-4, 4, 100),
        stats.norm.pdf(np.linspace(-4, 4, 100), loc=2),
        )
plt.fill_between(np.linspace(-4, 4, 100),
        stats.norm.pdf(np.linspace(-4, 4, 100), loc=2),
        alpha=.15
        )

# PDF MU = -2
plt.plot(np.linspace(-4, 4, 100),
        stats.norm.pdf(np.linspace(-4, 4, 100), loc=-2),
        )
plt.fill_between(np.linspace(-4, 4, 100),
        stats.norm.pdf(np.linspace(-4, 4, 100), loc=-2),
        alpha=.15
        )

# LEGEND
plt.text(x=-1, y=.35, s='$ \mu = 0 $', rotation=65, alpha=.75, weight='bold', color='#008fd5')
plt.text(x=1, y=.35, s='$ \mu = 2 $', rotation=65, alpha=.75, weight='bold', color='#fc4f30')
plt.text(x=-3, y=.35, s='$ \mu = -2 $', rotation=65, alpha=.75, weight='bold', color='#e5ae38')

# TICKS
plt.tick_params(axis='both', which='major', labelsize=18)
plt.axhline(y=0, color='black', linewidth=1.3, alpha=.7)

# TITLE
plt.text(x=-5, y=0.51, s='Normal Distibution - $ \mu $',
        fontsize=26, weight='bold', alpha=.75)
plt.text(x=-5, y=0.45,
        s='Depicted below are three normally distributed random variables with varying $ \\mu $. As one can easily\nsee the parameter $ \\mu $ shifts the distribution along the x-axis',
        fontsize=19, alpha=.85)
# Out:
# Text(-5, 0.45, 'Depicted below are three normally distributed random variables with varying $ \\mu $. As one can easily\nsee the parameter $ \\mu $ shifts the distribution along the x-axis')

# %% [markdown]
# ## 1.2 标准差($ \sigma $)

# %%
plt.figure(dpi=100)

# PDF SIGMA = 1
plt.plot(np.linspace(-4, 4, 100),
        stats.norm.pdf(np.linspace(-4, 4, 100)),
        )
plt.fill_between(np.linspace(-4, 4, 100),
        stats.norm.pdf(np.linspace(-4, 4, 100)),
        alpha=.15
        )

# PDF SIGMA = 2
plt.plot(np.linspace(-4, 4, 100),
        stats.norm.pdf(np.linspace(-4, 4, 100), scale=2),
        )
plt.fill_between(np.linspace(-4, 4, 100),
        stats.norm.pdf(np.linspace(-4, 4, 100), scale=2),
        alpha=.15
        )

# PDF SIGMA = 0.5
plt.plot(np.linspace(-4, 4, 100),
        stats.norm.pdf(np.linspace(-4, 4, 100), scale=0.5),
        )
plt.fill_between(np.linspace(-4, 4, 100),
        stats.norm.pdf(np.linspace(-4, 4, 100), scale=0.5),
        alpha=.15
        )

# LEGEND
plt.text(x=-1.3, y=.21, s='$ \sigma = 1 $', rotation=55, alpha=.75, weight='bold', color='#008fd5')
plt.text(x=-2.3, y=.12, s='$ \sigma = 2 $', rotation=25, alpha=.75, weight='bold', color='#fc4f30')
plt.text(x=-.6, y=.55, s='$ \sigma = 0.5 $', rotation=75, alpha=.75, weight='bold', color='#e5ae38')

# TICKS
plt.tick_params(axis='both', which='major', labelsize=18)
plt.axhline(y=0, color='black', linewidth=1.3, alpha=.7)

# TITLE
plt.text(x=-5, y=0.96, s='Normal Distibution - $ \sigma $',
        fontsize=26, weight='bold', alpha=.75)
plt.text(x=-5, y=0.85,
        s='Depicted below are three normally distributed random variables with varying $ \\sigma $. As one can easily\nsee the parameter $ \\sigma $ "sharpens" the distribution (the smaller $\\sigma$ the sharper the function).',
        fontsize=19, alpha=.85)
# Out:
# Text(-5, 0.85, 'Depicted below are three normally distributed random variables with varying $ \\sigma $. As one can easily\nsee the parameter $ \\sigma $ "sharpens" the distribution (the smaller $\\sigma$ the sharper the function).')

# %% [markdown]
# ## 1.3 随机样本
# 使用 norm.rvs()
# 其中默认值 $ \mu = 0 $ $ \sigma = 1 $
# 也可以自己指定，参数loc 表示 $ \mu $, scale 表示 $ \sigma $

# %%
from scipy.stats import norm

# 随机取一个数
print(norm.rvs())

# 随机取十个数
print(norm.rvs(size=10))

# 指定参数
print(norm.rvs(loc=10, scale=0.5))
# Out:
# -0.031241917356027986
# [ 0.32550699 -1.50500931 -1.64327723 -1.4595369   2.49805682 -0.70167834
#  -1.16794177 -0.90220121 -0.71163566 -0.95677672]
# 10.024327594412991

# %% [markdown]
# ## 1.4 概率密度函数（Probability Density Function)
# 根据密度分布函数计算

# %%
from scipy.stats import norm

import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (14, 7)

x = -1
y = 2

print('pdf(x) = {}\npdf(y) = {}'.format(norm.pdf(x), norm.pdf(y)))

x_s = np.linspace(-3, 3, 50)
y_s = norm.pdf(x_s)
plt.scatter(x_s, y_s)
# Out:
# pdf(x) = 0.24197072451914337
# pdf(y) = 0.05399096651318806

# %%
## 1.5 累积概率密度函数()
