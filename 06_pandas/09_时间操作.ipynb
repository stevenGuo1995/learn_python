# %%
## datetime操作时间
import datetime

datetime.date.today()
# Out:
# datetime.date(2019, 7, 16)

# %%
import time
datetime.date.fromtimestamp(time.time())
# Out:
# datetime.date(2019, 7, 16)

# %%
import pandas as pd
ts = pd.Timestamp('2019-07-16')
ts
# Out:
# Timestamp('2019-07-16 00:00:00')

# %%
data = pd.read_csv('./data/flowdata.csv')
data.head()
# Out:
#                   Time   L06_347  LS06_347  LS06_348
# 0  2009-01-01 00:00:00  0.137417  0.097500  0.016833
# 1  2009-01-01 03:00:00  0.131250  0.088833  0.016417
# 2  2009-01-01 06:00:00  0.113500  0.091250  0.016750
# 3  2009-01-01 09:00:00  0.135750  0.091500  0.016250
# 4  2009-01-01 12:00:00  0.140917  0.096167  0.017000

# %%
data['Time'] = pd.to_datetime(data['Time'])
data = data.set_index('Time')
data.head()
# Out:
#                       L06_347  LS06_347  LS06_348
# Time
# 2009-01-01 00:00:00  0.137417  0.097500  0.016833
# 2009-01-01 03:00:00  0.131250  0.088833  0.016417
# 2009-01-01 06:00:00  0.113500  0.091250  0.016750
# 2009-01-01 09:00:00  0.135750  0.091500  0.016250
# 2009-01-01 12:00:00  0.140917  0.096167  0.017000

# %%
data.index
# Out:
# DatetimeIndex(['2009-01-01 00:00:00', '2009-01-01 03:00:00',
#                '2009-01-01 06:00:00', '2009-01-01 09:00:00',
#                '2009-01-01 12:00:00', '2009-01-01 15:00:00',
#                '2009-01-01 18:00:00', '2009-01-01 21:00:00',
#                '2009-01-02 00:00:00', '2009-01-02 03:00:00',
#                ...
#                '2012-12-31 21:00:00', '2013-01-01 00:00:00',
#                '2013-01-01 03:00:00', '2013-01-01 06:00:00',
#                '2013-01-01 09:00:00', '2013-01-01 12:00:00',
#                '2013-01-01 15:00:00', '2013-01-01 18:00:00',
#                '2013-01-01 21:00:00', '2013-01-02 00:00:00'],
#               dtype='datetime64[ns]', name='Time', length=11697, freq=None)

# %%
data = pd.read_csv('./data/flowdata.csv', index_col=0, parse_dates=True)
data.head()
# Out:
#                       L06_347  LS06_347  LS06_348
# Time
# 2009-01-01 00:00:00  0.137417  0.097500  0.016833
# 2009-01-01 03:00:00  0.131250  0.088833  0.016417
# 2009-01-01 06:00:00  0.113500  0.091250  0.016750
# 2009-01-01 09:00:00  0.135750  0.091500  0.016250
# 2009-01-01 12:00:00  0.140917  0.096167  0.017000

# %%
data.index
# Out:
# DatetimeIndex(['2009-01-01 00:00:00', '2009-01-01 03:00:00',
#                '2009-01-01 06:00:00', '2009-01-01 09:00:00',
#                '2009-01-01 12:00:00', '2009-01-01 15:00:00',
#                '2009-01-01 18:00:00', '2009-01-01 21:00:00',
#                '2009-01-02 00:00:00', '2009-01-02 03:00:00',
#                ...
#                '2012-12-31 21:00:00', '2013-01-01 00:00:00',
#                '2013-01-01 03:00:00', '2013-01-01 06:00:00',
#                '2013-01-01 09:00:00', '2013-01-01 12:00:00',
#                '2013-01-01 15:00:00', '2013-01-01 18:00:00',
#                '2013-01-01 21:00:00', '2013-01-02 00:00:00'],
#               dtype='datetime64[ns]', name='Time', length=11697, freq=None)

# %%
data['2009-01-01 09:00':'2009-01-01 19:00']
# Out:
#                       L06_347  LS06_347  LS06_348
# Time
# 2009-01-01 09:00:00  0.135750  0.091500  0.016250
# 2009-01-01 12:00:00  0.140917  0.096167  0.017000
# 2009-01-01 15:00:00  0.099167  0.091667  0.017583
# 2009-01-01 18:00:00  0.132667  0.090167  0.016250

# %%
data['2013']
# Out:
#                       L06_347  LS06_347  LS06_348
# Time
# 2013-01-01 00:00:00  1.688333  1.688333  0.207333
# 2013-01-01 03:00:00  2.693333  2.693333  0.201500
# 2013-01-01 06:00:00  2.220833  2.220833  0.166917
# 2013-01-01 09:00:00  2.055000  2.055000  0.175667
# 2013-01-01 12:00:00  1.710000  1.710000  0.129583
# 2013-01-01 15:00:00  1.420000  1.420000  0.096333
# 2013-01-01 18:00:00  1.178583  1.178583  0.083083
# 2013-01-01 21:00:00  0.898250  0.898250  0.077167
# 2013-01-02 00:00:00  0.860000  0.860000  0.075000

# %%
data['2012-4':'2012-5']
# Out:
#                       L06_347  LS06_347  LS06_348
# Time
# 
# Out:
#                       L06_347  LS06_347  LS06_348
# Time
# 2009-01-01 09:00:00  0.135750  0.091500  0.016250
# 2009-01-02 09:00:00  0.141917  0.097083  0.016417
# 2009-01-03 09:00:00  0.124583  0.084417  0.015833
# 2009-01-04 09:00:00  0.109000  0.105167  0.018000
# 2009-01-05 09:00:00  0.161500  0.114583  0.021583
# 2009-01-06 09:00:00  0.100083  0.065583  0.015500
# 2009-01-07 09:00:00  0.138500  0.093917  0.015000
# 2009-01-08 09:00:00  0.101333  0.066417  0.016833
# 2009-01-09 09:00:00  0.061750  0.059417  0.015167
# 2009-01-10 09:00:00  0.193500  0.147000  0.013000
# 2009-01-11 09:00:00  0.080250  0.077417  0.013583
# 2009-01-12 09:00:00  0.132500  0.089167  0.016833
# 2009-01-13 09:00:00  0.196500  0.192667  0.045333
# 2009-01-14 09:00:00  0.322917  0.299250  0.029333
# 2009-01-15 09:00:00  0.210750  0.167500  0.025000
# 2009-01-16 09:00:00  0.157833  0.153917  0.023000
# 2009-01-17 09:00:00  0.218667  0.173333  0.022917
# 2009-01-18 09:00:00  0.633000  0.745667  0.077000
# ...

# %%
data.head()
# Out:
#                       L06_347  LS06_347  LS06_348
# Time
# 2009-01-01 00:00:00  0.137417  0.097500  0.016833
# 2009-01-01 03:00:00  0.131250  0.088833  0.016417
# 2009-01-01 06:00:00  0.113500  0.091250  0.016750
# 2009-01-01 09:00:00  0.135750  0.091500  0.016250
# 2009-01-01 12:00:00  0.140917  0.096167  0.017000

# %%
data.resample('D').mean()
# Out:
#              L06_347  LS06_347  LS06_348
# Time
# 2009-01-01  0.125010  0.092281  0.016635
# 2009-01-02  0.124146  0.095781  0.016406
# 2009-01-03  0.113562  0.085542  0.016094
# 2009-01-04  0.140198  0.102708  0.017323
# 2009-01-05  0.128812  0.104490  0.018167
# 2009-01-06  0.095771  0.067927  0.014521
# 2009-01-07  0.118646  0.083635  0.014344
# 2009-01-08  0.094323  0.070146  0.015073
# 2009-01-09  0.078156  0.058438  0.014021
# 2009-01-10  0.119917  0.093844  0.013573
# 2009-01-11  0.099646  0.071125  0.013833
# 2009-01-12  0.128260  0.094052  0.016229
# 2009-01-13  0.502802  0.598313  0.050271
# 2009-01-14  0.323896  0.309354  0.028594
# 2009-01-15  0.214188  0.185979  0.023729
# 2009-01-16  0.186208  0.149510  0.021479
# 2009-01-17  0.231333  0.203635  0.029323
# 2009-01-18  0.752271  0.874365  0.082292
# 2009-01-19  1.008813  1.266146  0.096240
# 2009-01-20  0.668687  0.785604  0.065646
# 2009-01-21  0.379271  0.377656  0.040781
# 2009-01-22  0.397917  0.403635  0.044469
# ...

# %%
data.resample('3D').max().head()
# Out:
#              L06_347  LS06_347  LS06_348
# Time
# 2009-01-01  0.147833  0.101917  0.017583
# 2009-01-04  0.161500  0.115167  0.021583
# 2009-01-07  0.139333  0.095750  0.018083
# 2009-01-10  0.193500  0.147000  0.018750
# 2009-01-13  1.158750  1.620000  0.104917

# %%
data.resample('M').mean().plot()

# %%
def test(n):
    for i in range(n):
        yield i**3

# %%
s = test(3)

# %%
for i in s:
    print(i)
# Out:
# 0
# 1
# 8

# %%
# Out:
# 1

# %%
# Out:
# 8
